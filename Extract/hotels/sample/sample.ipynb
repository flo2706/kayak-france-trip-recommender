# %%
import json
import os

# Paths
INPUT_FILE = os.path.join("..", "data", "hotels_descriptions.json")
OUTPUT_FILE = "hotels_descriptions_sample.json"

# Load the full dataset
with open(INPUT_FILE, "r", encoding="utf-8") as f:
    data = json.load(f)

# Save a sample of the first 5 entries
sample_data = data[:5]
with open(OUTPUT_FILE, "w", encoding="utf-8") as f:
    json.dump(sample_data, f, indent=4, ensure_ascii=False)

print(f"Sample créé: {OUTPUT_FILE}")
# Out:
# Sample créé: hotels_descriptions_sample.json
