# %%
import pandas as pd
import json
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# Load & open hotel descriptions JSON into a DataFrame
with open("../../Extract/hotels/data/hotels_descriptions.json", "r", encoding="utf-8") as f:
    data = json.load(f)  

# Convert the JSON data into a Pandas DataFrame for analysis
df_hotels = pd.DataFrame(data)
print(df_hotels.head())
# Out:
#   location                                               name rating  \
# 0    Rouen  Sous les Etoiles - dans le plus haut gratte-ci...    9,2
# 1    Rouen  L'Oasis Rouennais - Hypercentre - Gare rive Ga...     10
# 2    Rouen                   Radisson Blu Hotel, Rouen Centre    8,9
# 3    Paris                                Studio à Montmartre    8,0
# 4    Paris              Apartment Cosy 3P Quartier République   None
#
#                                                  url  \
# 0  https://www.booking.com/hotel/fr/sous-les-etoi...
# 1  https://www.booking.com/hotel/fr/oasis-rouenna...
# 2  https://www.booking.com/hotel/fr/radisson-blu-...
# 3  https://www.booking.com/hotel/fr/studio-a-mont...
# 4  https://www.booking.com/hotel/fr/apartment-cos...
#
#                                          description  \
# 0  L’hébergement Sous les Etoiles - dans le plus ...
# 1  L’hébergement L'Oasis Rouennais - Hypercentre ...
# 2  L’établissement Radisson Blu Hotel, Rouen Cent...
# 3  Offrant une vue sur le jardin, l’hébergement S...
# 4  Doté d’une connexion Wi-Fi gratuite, l’héberge...
#
#                      coordinates
# 0           49.4400384,1.0856876
# 1           49.4480098,1.0955547
# 2              49.446441,1.09412
# 3  48.8915065,2.3385854999999998
# 4           48.8681307,2.3586776

# %%
# Check for missing values in the dataset
# Count the number of NULL values per column
print("Number of NULL values per column:")
print(df_hotels.isnull().sum())

# Display rows that contain at least one NULL value
print("\nRows containing at least one NULL value:")
print(df_hotels[df_hotels.isnull().any(axis=1)])
# Out:
# Number of NULL values per column:
# location        0
# name            0
# rating         18
# url             0
# description     1
# coordinates     0
# dtype: int64
#
# Rows containing at least one NULL value:
#                          location  \
# 4                           Paris
# 33                          Dijon
# 107  Chateau du Haut Koenigsbourg
# 313                         Paris
# 315                         Paris
# 318                         Paris
# 323                         Paris
# 356                         Paris
# 452                     Montauban
# 469                        Ariege
# 471                        Ariege
# 626               Aix en Provence
# 627               Aix en Provence
# 646      Saintes Maries de la mer
# 712                        Cassis
# 744            Bormes les Mimosas
# 778                          Lyon
# 784                          Lyon
# 836                   La Rochelle
#
#                                                   name rating  \
# 4                Apartment Cosy 3P Quartier République   None
# 33             Mini loft de Charme au cœur de la ville   None
# 107                                 Au pied du Château   None
# 313      Spacious 1BR in the Heart of Paris & Pompidou   None
# 315             Gare de Lyon - charmant studio moderne   None
# 318   11 Joubert - Joli studio 1PAX Galeries Lafayette   None
# 323          Confortable studio canal Saint Martin 10e   None
# 356                   Flexliving - studio - Boulangers   None
# 452                          Montauban City Zen & Cosy    7,3
# 469  Chalet enchanteur à Tarascon-sur-Ariège avec v...   None
# 471                           Gite du Domaine Laffraut   None
# 626                Studio Elegant dans le Centre Ville   None
# 627                  Logement proximité cours Mirabeau   None
# 646  Appartement - balcon vue mer - place de parking -   None
# 712                       Lou Pichot par Dodo à Cassis   None
# 744  Spacious House with Large Terrace & Traditiona...   None
# 778  Le Blandan Spacious and Cozy Apartment - Lyon 1st   None
# 784   Loft au coeur de Croix-Rousse - Lyon pour 2 pers   None
# 836            Cozy Apartment In La Rochelle With Wifi   None
#
#                                                    url  \
# 4    https://www.booking.com/hotel/fr/apartment-cos...
# 33   https://www.booking.com/hotel/fr/mini-loft-de-...
# 107  https://www.booking.com/hotel/fr/au-pied-du-ch...
# 313  https://www.booking.com/hotel/fr/bright-1br-in...
# 315  https://www.booking.com/hotel/fr/gare-de-lyon-...
# 318  https://www.booking.com/hotel/fr/11-joubert-jo...
# 323  https://www.booking.com/hotel/fr/confortable-s...
# 356  https://www.booking.com/hotel/fr/flexliving-st...
# 452  https://www.booking.com/hotel/fr/montauban-cit...
# 469  https://www.booking.com/hotel/fr/chalet-d-une-...
# 471  https://www.booking.com/hotel/fr/gite-du-domai...
# 626  https://www.booking.com/hotel/fr/studio-elegan...
# 627  https://www.booking.com/hotel/fr/logement-prox...
# 646  https://www.booking.com/hotel/fr/appartement-b...
# 712  https://www.booking.com/hotel/fr/agavnian-par-...
# 744  https://www.booking.com/hotel/fr/quiet-and-spa...
# 778  https://www.booking.com/hotel/fr/le-blandan-sp...
# 784  https://www.booking.com/hotel/fr/loft-au-coeur...
# 836  https://www.booking.com/hotel/fr/cozy-apartmen...
#
#                                            description  \
# 4    Doté d’une connexion Wi-Fi gratuite, l’héberge...
# 33   L’hébergement Mini loft de Charme au cœur de l...
# 107  L’hébergement Au pied du Château se trouve à O...
# 313  Offrant une vue sur la ville et doté d’une con...
# 315  L’établissement Gare de Lyon - charmant studio...
# 318  L’hébergement 11 Joubert - Joli studio 1PAX Ga...
# 323  L’hébergement Confortable studio canal Saint M...
# 356  Doté d’une connexion Wi-Fi gratuite, l’héberge...
# 452                                               None
# 469  L’hébergement Chalet enchanteur à Tarascon-sur...
# 471  Situé à Tarascon-sur-Ariège, l’hébergement Git...
# 626  L’hébergement Studio Elegant dans le Centre Vi...
# 627  L’hébergement Logement proximité cours Mirabea...
# 646  Proposant une terrasse et offrant une vue sur ...
# 712  L’hébergement Lou Pichot par Dodo à Cassis vou...
# 744  L’hébergement Spacious House with Large Terrac...
# 778  L’hébergement Le Blandan Spacious and Cozy Apa...
# 784  Doté d’une connexion Wi-Fi gratuite, l’héberge...
# 836  L’hébergement Cozy Apartment In La Rochelle Wi...
#
#                                coordinates
# 4                     48.8681307,2.3586776
# 33       47.3240631825947,5.03953477948697
# 107                   48.2484025,7.3548257
# 313  48.863400729011346,2.3490426423258457
# 315                   48.8369745,2.4018481
# 318                   48.8745421,2.3316074
# 323                    48.8744902,2.365101
# 356    48.84595884733942,2.354252421461087
# 452           44.016598,1.3727340000000368
# 469   42.85265452283117,1.5952209617629842
# 471                   42.8519634,1.6039854
# 626                   43.5276672,5.4465471
# 627         43.522791295057,5.452297959287
# 646                     43.453312,4.435338
# 712                   43.2120468,5.5426978
# 744                   43.1472634,6.3367261
# 778                   45.7685541,4.8291923
# 784                   45.7709544,4.8346546
# 836                      46.15022,-1.15418

# %%
# Inspect hotels with missing ratings 
# Filter the DataFrame to show only rows where 'rating' is NaN
print("Hotels without rating:")
print(df_hotels[df_hotels["rating"].isna()])
# Out:
# Hotels without rating:
#                          location  \
# 4                           Paris
# 33                          Dijon
# 107  Chateau du Haut Koenigsbourg
# 313                         Paris
# 315                         Paris
# 318                         Paris
# 323                         Paris
# 356                         Paris
# 469                        Ariege
# 471                        Ariege
# 626               Aix en Provence
# 627               Aix en Provence
# 646      Saintes Maries de la mer
# 712                        Cassis
# 744            Bormes les Mimosas
# 778                          Lyon
# 784                          Lyon
# 836                   La Rochelle
#
#                                                   name rating  \
# 4                Apartment Cosy 3P Quartier République   None
# 33             Mini loft de Charme au cœur de la ville   None
# 107                                 Au pied du Château   None
# 313      Spacious 1BR in the Heart of Paris & Pompidou   None
# 315             Gare de Lyon - charmant studio moderne   None
# 318   11 Joubert - Joli studio 1PAX Galeries Lafayette   None
# 323          Confortable studio canal Saint Martin 10e   None
# 356                   Flexliving - studio - Boulangers   None
# 469  Chalet enchanteur à Tarascon-sur-Ariège avec v...   None
# 471                           Gite du Domaine Laffraut   None
# 626                Studio Elegant dans le Centre Ville   None
# 627                  Logement proximité cours Mirabeau   None
# 646  Appartement - balcon vue mer - place de parking -   None
# 712                       Lou Pichot par Dodo à Cassis   None
# 744  Spacious House with Large Terrace & Traditiona...   None
# 778  Le Blandan Spacious and Cozy Apartment - Lyon 1st   None
# 784   Loft au coeur de Croix-Rousse - Lyon pour 2 pers   None
# 836            Cozy Apartment In La Rochelle With Wifi   None
#
#                                                    url  \
# 4    https://www.booking.com/hotel/fr/apartment-cos...
# 33   https://www.booking.com/hotel/fr/mini-loft-de-...
# 107  https://www.booking.com/hotel/fr/au-pied-du-ch...
# 313  https://www.booking.com/hotel/fr/bright-1br-in...
# 315  https://www.booking.com/hotel/fr/gare-de-lyon-...
# 318  https://www.booking.com/hotel/fr/11-joubert-jo...
# 323  https://www.booking.com/hotel/fr/confortable-s...
# 356  https://www.booking.com/hotel/fr/flexliving-st...
# 469  https://www.booking.com/hotel/fr/chalet-d-une-...
# 471  https://www.booking.com/hotel/fr/gite-du-domai...
# 626  https://www.booking.com/hotel/fr/studio-elegan...
# 627  https://www.booking.com/hotel/fr/logement-prox...
# 646  https://www.booking.com/hotel/fr/appartement-b...
# 712  https://www.booking.com/hotel/fr/agavnian-par-...
# 744  https://www.booking.com/hotel/fr/quiet-and-spa...
# 778  https://www.booking.com/hotel/fr/le-blandan-sp...
# 784  https://www.booking.com/hotel/fr/loft-au-coeur...
# 836  https://www.booking.com/hotel/fr/cozy-apartmen...
#
#                                            description  \
# 4    Doté d’une connexion Wi-Fi gratuite, l’héberge...
# 33   L’hébergement Mini loft de Charme au cœur de l...
# 107  L’hébergement Au pied du Château se trouve à O...
# 313  Offrant une vue sur la ville et doté d’une con...
# 315  L’établissement Gare de Lyon - charmant studio...
# 318  L’hébergement 11 Joubert - Joli studio 1PAX Ga...
# 323  L’hébergement Confortable studio canal Saint M...
# 356  Doté d’une connexion Wi-Fi gratuite, l’héberge...
# 469  L’hébergement Chalet enchanteur à Tarascon-sur...
# 471  Situé à Tarascon-sur-Ariège, l’hébergement Git...
# 626  L’hébergement Studio Elegant dans le Centre Vi...
# 627  L’hébergement Logement proximité cours Mirabea...
# 646  Proposant une terrasse et offrant une vue sur ...
# 712  L’hébergement Lou Pichot par Dodo à Cassis vou...
# 744  L’hébergement Spacious House with Large Terrac...
# 778  L’hébergement Le Blandan Spacious and Cozy Apa...
# 784  Doté d’une connexion Wi-Fi gratuite, l’héberge...
# 836  L’hébergement Cozy Apartment In La Rochelle Wi...
#
#                                coordinates
# 4                     48.8681307,2.3586776
# 33       47.3240631825947,5.03953477948697
# 107                   48.2484025,7.3548257
# 313  48.863400729011346,2.3490426423258457
# 315                   48.8369745,2.4018481
# 318                   48.8745421,2.3316074
# 323                    48.8744902,2.365101
# 356    48.84595884733942,2.354252421461087
# 469   42.85265452283117,1.5952209617629842
# 471                   42.8519634,1.6039854
# 626                   43.5276672,5.4465471
# 627         43.522791295057,5.452297959287
# 646                     43.453312,4.435338
# 712                   43.2120468,5.5426978
# 744                   43.1472634,6.3367261
# 778                   45.7685541,4.8291923
# 784                   45.7709544,4.8346546
# 836                      46.15022,-1.15418

# %%
# Count missing ratings per city 
missing_ratings = df_hotels[df_hotels["rating"].isna()]   # filter only missing ratings
missing_count = missing_ratings["location"].value_counts() 

plt.figure(figsize=(10, 6))
missing_count.plot(kind="bar", color="tomato", edgecolor="black")

plt.title("Nombre d'hôtels sans rating par ville", fontsize=14)
plt.xlabel("Ville", fontsize=12)
plt.ylabel("Nombre de rating manquants", fontsize=12)
plt.xticks(rotation=45, ha="right")
plt.tight_layout()
plt.show()

# %%
# Clean the 'rating' column 
# Replace commas with dots and convert to float
df_hotels["rating_clean"] = (
    df_hotels["rating"]
    .str.replace(",", ".", regex=False)
    .astype(float)
)

# Plot histogram + density curve 
plt.figure(figsize=(8, 5))
sns.histplot(
    df_hotels["rating_clean"].dropna(),
    bins=15,
    kde=True,                
    color="skyblue",
    edgecolor="black"
)

plt.title("Distribution des rating", fontsize=14)
plt.xlabel("Rating", fontsize=12)
plt.ylabel("Nombre d'hôtels", fontsize=12)
plt.grid(axis="y", alpha=0.4)
plt.tight_layout()
plt.show()

# %%
best_hotel_per_city = (
    df_hotels.loc[df_hotels.groupby("location")["rating"].idxmax(), ["location", "name", "rating"]]
    .sort_values(by="rating", ascending=False)
    .reset_index(drop=True)
)

best_hotel_per_city
# Out:
#                         location  \
# 0                  Aigues Mortes
# 1                         Bayeux
# 2                       Grenoble
# 3                         Cassis
# 4                           Uzes
# 5                        Avignon
# 6   Chateau du Haut Koenigsbourg
# 7                     Saint-Malo
# 8                     N%C3%AEmes
# 9                      Marseille
# 10                        Ariege
# 11              Gorges du Verdon
# 12               Aix en Provence
# 13                   La Rochelle
# 14                     Eguisheim
# 15                        Colmar
# 16                         Dijon
# 17                   Carcassonne
# 18      Saintes Maries de la mer
# 19                         Paris
# 20                      Toulouse
# 21                     Montauban
# 22                     Collioure
# 23            Bormes les Mimosas
# 24          Le Mont-Saint-Michel
# 25                      Biarritz
# 26                        Annecy
# 27                         Lille
# 28                      Le Havre
# 29                        Amiens
# 30                      Besancon
# 31                         Rouen
# 32                       Bayonne
# 33                    Strasbourg
# 34                          Lyon
#
#                                                  name rating
# 0          La maison blanche Intra-Muros Free parking    9,9
# 1                                           L'Atelier    9,9
# 2   Appartement Hagaki vue panoramique proche gare...    9,9
# 3    LE SEPT charmant studio aux portes des calanques    9,9
# 4                                    La DAME de FLAUX    9,9
# 5   Apartment 40m2-Air conditioning-Elevator-Under...    9,8
# 6                                         Villa Grimm    9,8
# 7                    Studio Le sillon malouin vue mer    9,8
# 8                       Appartement T3 proches arènes    9,8
# 9                          SV - Au Pied du Vieux Port    9,8
# 10                                 La cabane a Joseph    9,8
# 11  Spacieuse Dépendance Duplex 50 M2 Classé 3 éto...    9,8
# 12                 Le Discret - Un Voyage en Provence    9,8
# 13       Appartement de charme au Marche avec parking    9,8
# 14                                     Fleur de Vigne    9,8
# 15                                   Gite Bim Maidala    9,7
# 16           Le petit POTE' studio Dijon hyper centre    9,7
# 17                  LA COUR CARREE - chambres d'hôtes    9,7
# 18                          Entre ciel et bord de mer    9,7
# 19                         PARISIAN HOME l MONTMARTRE    9,7
# 20                                     Toucan by Yumē    9,6
# 21  La Halte Occitane - Classé 3 étoiles - Pour 6 ...    9,6
# 22            Collioure Vue Mer Parking Gratuit Fibre    9,6
# 23  Studio Liège, vue mer au village de Bormes les...    9,6
# 24              Roulotte au pied du Mont Saint Michel    9,5
# 25  L'océan à perte de vue, la grande plage à vos ...    9,5
# 26               L'Anneciano - Balcon - Chambre - Vue    9,5
# 27                          galerie jacqueline storme    9,4
# 28  Le Parc, logement de charme avec SPA privatif ...    9,4
# 29                                   Maison Longuevie    9,4
# 30                        La Romantica by La Felicità    9,3
# 31         Charmants 2 pièces - Hyper centre de Rouen    9,3
# 32                       Appartement T2 cosy et calme    9,3
# 33                             Nid douillet de la pie    9,3
# 34                                       Pullman Lyon    9,1
